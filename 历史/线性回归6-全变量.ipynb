# 93 -0.107649 -0.108629 -0.108893 -0.109857 -0.109623 -0.110873 -0.110119
# ..       ...       ...       ...       ...       ...       ...       ...
# 35 -0.433851 -0.434754 -0.435472 -0.436080 -0.436530 -0.437006 -0.435673
# 55 -0.303861 -0.304534 -0.304997 -0.305491 -0.305581 -0.306270 -0.305994
# 85 -0.266729 -0.267859 -0.268083 -0.269010 -0.268791 -0.270011 -0.269103
# 71 -0.230854 -0.231923 -0.232343 -0.233281 -0.233108 -0.234452 -0.233843
# 34 -0.289967 -0.290950 -0.291618 -0.292030 -0.292519 -0.293193 -0.292598
#
#       lgA250
# 70 -0.362374
# 51 -0.374529
# 10 -0.281640
# 22 -0.375562
# 93 -0.109130
# ..       ...
# 35 -0.435792
# 55 -0.304623
# 85 -0.268839
# 71 -0.233545
# 34 -0.291192
#
# [107 rows x 2004 columns]

# %%
y_train = df.iloc[0:60, 2:3]
x_train = df.iloc[0:60, 3:2004]

y_test = df.iloc[60:80, 2:3]
x_test = df.iloc[60:80, 3:2004]

y_validation = df.iloc[80:, 2:3]
x_validation = df.iloc[80:, 3:2004]

Y_total = df.iloc[:, 2:3]
X_total = df.iloc[:, 3:2004]

# %%
#归一化
scaler = MinMaxScaler().fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)
x_validation = scaler.transform(x_validation)

#总体
X_total = scaler.transform(X_total)

# %%
#降维
pca = PCA(n_components = 60)
pca.fit(x_train)
x_train = pca.transform(x_train)
x_test = pca.transform(x_test)
x_validation = pca.transform(x_validation)
X_total = pca.transform(X_total)
x_train.shape
# Out:
# (60, 60)

# %%
x = x_train
y = y_train
# reg = linear_model.LinearRegression() #--- 线性回归
# reg = linear_model.Ridge(alpha=0.7)  #----r2 0.75
reg = linear_model.Lasso(alpha=0.2, max_iter = 100000)
# reg = linear_model.HuberRegressor(max_iter=100000, epsilon=1.2)
reg.fit(x, np.ravel(y))
x_train.shape
# Out:
# (60, 60)

# %%
y_train_predict = reg.predict(x_train)
y_test_predict = reg.predict(x_test)
y_validation_predict = reg.predict(x_validation)
y_test_predict
# Out:
# array([32.05488797, 34.11813281, 21.48036959, 33.49212463, 33.964618  ,
#        29.3969194 , 35.0079577 , 29.7399613 , 32.52710563, 32.59194586,
#        35.50519499, 35.75514277, 33.47486952, 34.20041372, 29.57987265,
#        32.00182894, 30.95576201, 30.52938543, 33.40332729, 29.51549235])

# %%
r2_score(y_train, y_train_predict)
# Out:
# 0.821445935511708

# %%
r2_score(y_test, y_test_predict)
# Out:
# 0.5641575474663862

# %%
r2_score(y_validation, y_validation_predict)
# Out:
# 0.3393079576536475

# %%
Y_total_predict = reg.predict(X_total)

r2_score(Y_total,Y_total_predict)
# Out:
# 0.6938167646519615

# %%
#df.to_csv('huber_noindex.csv',encoding='utf-8_sig',index=None)
